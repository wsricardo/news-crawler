# %% [markdown]
# # Dados Notícias e Views com Pandas

# %%
import pandas as pd
import numpy
import requests
import json
import datetime
from bs4 import BeautifulSoup
import os
import sys
import glob

# %%
datajsonfiles = glob.glob('/home/user/news-crawler/datanews/*.json')

# %%
df = [ pd.read_json( files ) for files in datajsonfiles ] 

df[0]
# Out:
#                                                 title  \
# 0   Imprensa internacional repercute escândalo no ...
# 1   Instagram volta a funcionar depois de mais de ...
# 2   Flamengo derrota o Corinthians com gol nos acr...
# 3   Com golaço de Suárez, Grêmio vence e afunda In...
# 4   Congresso vota nova regra fiscal e define plan...
# ..                                                ...
# 62                 Parceiros comerciais da BBC Brasil
# 63  CÚPULA DO G7 “A decepção foi de Lula”, diz Zel...
# 64  Flamengo vence Corinthians e mantém rival na z...
# 65  Brasileiro Vinicius Jr. é vítima de mais um ca...
# 66  Bíblia Hebraica mais antiga do mundo é vendida...
#
#                                                  href
# 0   https://g1.globo.com/go/goias/noticia/2023/05/...
# 1   https://g1.globo.com/tecnologia/noticia/2023/0...
# 2   https://ge.globo.com/rj/futebol/brasileirao-se...
# 3   https://ge.globo.com/rs/futebol/brasileirao-se...
# 4   https://g1.globo.com/politica/noticia/2023/05/...
# ..                                                ...
# 62  https://www.bbc.com/portuguese/institutional-4...
# 63  https://www.cnnbrasil.com.br/internacional/a-d...
# 64  https://www.cnnbrasil.com.br/esportes/nos-acre...
# 65  https://www.cnnbrasil.com.br/esportes/vinicius...
# 66  https://www.cnnbrasil.com.br/internacional/bib...
#
# [67 rows x 2 columns]

# %%
# Concatenate dataframes list
dff = pd.concat( df )

# Rename columns
#for i in dff:
#    i.rename( columns={ 'title': 'Title' }, inplace = True  )
#    i.rename( columns={ 'href': 'Link' }, inplace = True )

dff.rename( columns={ 'title': 'Title' }, inplace = True   )
dff.rename( columns={ 'href': 'Link' }, inplace = True )


dff.drop_duplicates(inplace=True, ignore_index=True)
    
dff
# Out:
#                                                   Title  \
# 0     Imprensa internacional repercute escândalo no ...
# 1     Instagram volta a funcionar depois de mais de ...
# 2     Flamengo derrota o Corinthians com gol nos acr...
# 3     Com golaço de Suárez, Grêmio vence e afunda In...
# 4     Congresso vota nova regra fiscal e define plan...
# ...                                                 ...
# 1052  Lira diz que há "insatisfação generalizada" no...
# 1053  AO VIVO: Câmara debate MP que reorganiza minis...
# 1054  Lula assume negociação em busca de votos para ...
# 1055  "Tá na cara que é racismo", diz Datena sobre i...
# 1056  Saiba quem são as mulheres que deram banana pa...
#
#                                                    Link
# 0     https://g1.globo.com/go/goias/noticia/2023/05/...
# 1     https://g1.globo.com/tecnologia/noticia/2023/0...
# 2     https://ge.globo.com/rj/futebol/brasileirao-se...
# 3     https://ge.globo.com/rs/futebol/brasileirao-se...
# 4     https://g1.globo.com/politica/noticia/2023/05/...
# ...                                                 ...
# 1052  https://www.band.uol.com.br/noticias/lira-diz-...
# 1053  https://www.band.uol.com.br/noticias/ao-vivo/c...
# 1054  https://www.band.uol.com.br/noticias/jornal-da...
# 1055  https://www.band.uol.com.br/noticias/brasil-ur...
# 1056  https://www.band.uol.com.br/noticias/quem-sao-...
#
# [1057 rows x 2 columns]

# %%
# Remove lines specified to link of Twitter
v = [ 'Política',
    'Pop',
    'Economia',
    'Internacional',
    'Viagem & Gastronomia',
    'Nacional',
    'Saúde',
    'Esportes',
    'CNN Plural',
    'Ciência e Tecnologia',
    'Mercado',
    'Facebook',
    'Twitter',
    'Youtube',
    'YouTube',
    'Instagram' 
    ]

for i in v:
    dff = dff.drop( index=dff.index[  dff['Title'] == i  ] )
"""
dff = dff.drop( index=dff.index[  dff['Title'] == 'Twitter'  ][0] )
dff = dff.drop( index=dff.index[  dff['Title'] == 'Facebook'  ][0] )
dff = dff.drop( index=dff.index[  dff['Title'] == 'Instagram'  ][0] )
dff = dff.drop( index=dff.index[  dff['Title'] == 'Youtube'  ][0] )
dff = dff.drop( index=dff.index[  dff['Title'] == 'Política'  ][0] )"""
dff
# Out:
#                                                   Title  \
# 0     Imprensa internacional repercute escândalo no ...
# 1     Instagram volta a funcionar depois de mais de ...
# 2     Flamengo derrota o Corinthians com gol nos acr...
# 3     Com golaço de Suárez, Grêmio vence e afunda In...
# 4     Congresso vota nova regra fiscal e define plan...
# ...                                                 ...
# 1052  Lira diz que há "insatisfação generalizada" no...
# 1053  AO VIVO: Câmara debate MP que reorganiza minis...
# 1054  Lula assume negociação em busca de votos para ...
# 1055  "Tá na cara que é racismo", diz Datena sobre i...
# 1056  Saiba quem são as mulheres que deram banana pa...
#
#                                                    Link
# 0     https://g1.globo.com/go/goias/noticia/2023/05/...
# 1     https://g1.globo.com/tecnologia/noticia/2023/0...
# 2     https://ge.globo.com/rj/futebol/brasileirao-se...
# 3     https://ge.globo.com/rs/futebol/brasileirao-se...
# 4     https://g1.globo.com/politica/noticia/2023/05/...
# ...                                                 ...
# 1052  https://www.band.uol.com.br/noticias/lira-diz-...
# 1053  https://www.band.uol.com.br/noticias/ao-vivo/c...
# 1054  https://www.band.uol.com.br/noticias/jornal-da...
# 1055  https://www.band.uol.com.br/noticias/brasil-ur...
# 1056  https://www.band.uol.com.br/noticias/quem-sao-...
#
# [1057 rows x 2 columns]

# %%
dff = dff.drop_duplicates(ignore_index=True)

# %%
dff
#dff2 = dff.drop(dff.index[  dff['Title'] == 'Twitter'  ][0])
#dff2.iloc[66]
#dff.iloc[dff.index[  dff['Title'] == 'Twitter'  ][0]]
# Out:
#                                                   Title  \
# 0     Imprensa internacional repercute escândalo no ...
# 1     Instagram volta a funcionar depois de mais de ...
# 2     Flamengo derrota o Corinthians com gol nos acr...
# 3     Com golaço de Suárez, Grêmio vence e afunda In...
# 4     Congresso vota nova regra fiscal e define plan...
# ...                                                 ...
# 1052  Lira diz que há "insatisfação generalizada" no...
# 1053  AO VIVO: Câmara debate MP que reorganiza minis...
# 1054  Lula assume negociação em busca de votos para ...
# 1055  "Tá na cara que é racismo", diz Datena sobre i...
# 1056  Saiba quem são as mulheres que deram banana pa...
#
#                                                    Link
# 0     https://g1.globo.com/go/goias/noticia/2023/05/...
# 1     https://g1.globo.com/tecnologia/noticia/2023/0...
# 2     https://ge.globo.com/rj/futebol/brasileirao-se...
# 3     https://ge.globo.com/rs/futebol/brasileirao-se...
# 4     https://g1.globo.com/politica/noticia/2023/05/...
# ...                                                 ...
# 1052  https://www.band.uol.com.br/noticias/lira-diz-...
# 1053  https://www.band.uol.com.br/noticias/ao-vivo/c...
# 1054  https://www.band.uol.com.br/noticias/jornal-da...
# 1055  https://www.band.uol.com.br/noticias/brasil-ur...
# 1056  https://www.band.uol.com.br/noticias/quem-sao-...
#
# [1057 rows x 2 columns]

# %%
dff.to_csv('data/news.csv',  index=False)
dff.to_excel('data/news.xlsx',  index=False)

# %%
dff.to_json( 'data/news.json' , orient='records')

# %%
def dfcleans( df ):
    
    """
    Remove fields by title in list of names specifieds.
    """
    
    # Remove lines specified to link of Twitter
    v = [ 'Política',
        'Pop',
        'Economia',
        'Internacional',
        'Viagem & Gastronomia',
        'Nacional',
        'Saúde',
        'Esportes',
        'CNN Plural',
        'Ciência e Tecnologia',
        'Mercado',
        'Facebook',
        'Twitter',
        'Youtube',
        'YouTube',
        'Instagram' 
    ]
    for i in v:
        df = df.drop( index=df.index[  df['Title'] == i  ] )
        
    df = df.drop_duplicates( ignore_index = True )
    return df.to_json( orient='records' )

# %%
import json

# %%
d = json.loads( dfcleans( dff ) )
d[:10]
# Out:
# [{'Title': 'Imprensa internacional repercute escândalo no futebol brasileiro',
#   'Link': 'https://g1.globo.com/go/goias/noticia/2023/05/21/imprensa-internacional-repercute-escandalo-no-futebol-brasileiro-apos-manipulacao-de-resultados-com-esquema-de-apostas.ghtml'},
#  {'Title': 'Instagram volta a funcionar depois de mais de uma hora fora do ar',
#   'Link': 'https://g1.globo.com/tecnologia/noticia/2023/05/21/instagram-fica-fora-do-ar-neste-domingo.ghtml'},
#  {'Title': 'Flamengo derrota o Corinthians com gol nos acréscimos',
#   'Link': 'https://ge.globo.com/rj/futebol/brasileirao-serie-a/jogo/21-05-2023/flamengo-corinthians.ghtml'},
#  {'Title': 'Com golaço de Suárez, Grêmio vence e afunda Inter na crise',
#   'Link': 'https://ge.globo.com/rs/futebol/brasileirao-serie-a/jogo/21-05-2023/gremio-internacional.ghtml'},
#  {'Title': 'Congresso vota nova regra fiscal e define plano de trabalho para 3 CPIs',
#   'Link': 'https://g1.globo.com/politica/noticia/2023/05/21/congresso-tera-semana-com-cpis-e-votacao-do-novo-arcabouco-fiscal.ghtml'},
#  {'Title': 'Autoridades atribuem a facções morte de pessoas que participavam de rali',
#   'Link': 'https://g1.globo.com/mundo/noticia/2023/05/21/massacre-no-mexico-autoridades-atribuem-a-criminosos-morte-de-10-pessoas-que-participavam-de-rali.ghtml'},
#  {'Title': 'Água da Fontana di Trevi é tingida de preto em ato pelo clima',
#   'Link': 'https://g1.globo.com/mundo/noticia/2023/05/21/agua-da-fontana-di-trevi-escurece-em-protesto-pelo-clima-em-roma.ghtml'},
#  {'Title': '4 fatores que explicam a nova desaceleração econômica na Venezuela',
#   'Link': 'https://www.bbc.com/portuguese/articles/cw4p2lxdyzjo'},
#  {'Title': 'Como nossa mente nos faz repetir os erros e o que fazer para evitar isso',
#   'Link': 'https://www.bbc.com/portuguese/articles/c4nw80547plo'},
#  {'Title': 'O encontro entre Lula e Zelensky que não aconteceu - e mais 3 destaques da cúpula do G7',
#   'Link': 'https://www.bbc.com/portuguese/articles/c51pe7vn9y5o'}]

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#                                                   Title  \
# 0     Imprensa internacional repercute escândalo no ...
# 1     Instagram volta a funcionar depois de mais de ...
# 2     Flamengo derrota o Corinthians com gol nos acr...
# 3     Com golaço de Suárez, Grêmio vence e afunda In...
# 4     Congresso vota nova regra fiscal e define plan...
# ...                                                 ...
# 1052  Lira diz que há "insatisfação generalizada" no...
# 1053  AO VIVO: Câmara debate MP que reorganiza minis...
# 1054  Lula assume negociação em busca de votos para ...
# 1055  "Tá na cara que é racismo", diz Datena sobre i...
# 1056  Saiba quem são as mulheres que deram banana pa...
#
#                                                    Link
# 0     https://g1.globo.com/go/goias/noticia/2023/05/...
# 1     https://g1.globo.com/tecnologia/noticia/2023/0...
# 2     https://ge.globo.com/rj/futebol/brasileirao-se...
# 3     https://ge.globo.com/rs/futebol/brasileirao-se...
# 4     https://g1.globo.com/politica/noticia/2023/05/...
# ...                                                 ...
# 1052  https://www.band.uol.com.br/noticias/lira-diz-...
# 1053  https://www.band.uol.com.br/noticias/ao-vivo/c...
# 1054  https://www.band.uol.com.br/noticias/jornal-da...
# 1055  https://www.band.uol.com.br/noticias/brasil-ur...
# 1056  https://www.band.uol.com.br/noticias/quem-sao-...
#
# [1057 rows x 2 columns]

# %%
df.to_csv('data/news.csv', index=False)

# %%
df.to_json('data/news.json')

# %%
df.to_excel('data/news.xlsx')
