# %% [markdown]
# # Dados Notícias e Views com Pandas

# %%
import pandas as pd
import numpy
import requests
import json
import datetime
from bs4 import BeautifulSoup
import os
import sys
import glob

# %%
datajsonfiles = glob.glob('/home/user/news-crawler/datanews/*.json')

# %%
df = [ pd.read_json( files ) for files in datajsonfiles ] 

df[0]
# Out:
#                                                 title  \
# 0   Imprensa internacional repercute escândalo no ...
# 1   Instagram volta a funcionar depois de mais de ...
# 2   Flamengo derrota o Corinthians com gol nos acr...
# 3   Com golaço de Suárez, Grêmio vence e afunda In...
# 4   Congresso vota nova regra fiscal e define plan...
# ..                                                ...
# 76                                              Saúde
# 77                                           Esportes
# 78                                         CNN Plural
# 79                               Ciência e Tecnologia
# 80  Bíblia Hebraica mais antiga do mundo é vendida...
#
#                                                  href
# 0   https://g1.globo.com/go/goias/noticia/2023/05/...
# 1   https://g1.globo.com/tecnologia/noticia/2023/0...
# 2   https://ge.globo.com/rj/futebol/brasileirao-se...
# 3   https://ge.globo.com/rs/futebol/brasileirao-se...
# 4   https://g1.globo.com/politica/noticia/2023/05/...
# ..                                                ...
# 76                https://www.cnnbrasil.com.br/saude/
# 77             https://www.cnnbrasil.com.br/esportes/
# 78  https://www.cnnbrasil.com.br/tudo-sobre/cnn-pl...
# 79           https://www.cnnbrasil.com.br/tecnologia/
# 80  https://www.cnnbrasil.com.br/internacional/bib...
#
# [81 rows x 2 columns]

# %%
# Concatenate dataframes list
dff = pd.concat( df )

# Rename columns
#for i in dff:
#    i.rename( columns={ 'title': 'Title' }, inplace = True  )
#    i.rename( columns={ 'href': 'Link' }, inplace = True )

dff.rename( columns={ 'title': 'Title' }, inplace = True   )
dff.rename( columns={ 'href': 'Link' }, inplace = True )


dff.drop_duplicates(inplace=True, ignore_index=True)
    
dff
# Out:
#                                                  Title  \
# 0    Imprensa internacional repercute escândalo no ...
# 1    Instagram volta a funcionar depois de mais de ...
# 2    Flamengo derrota o Corinthians com gol nos acr...
# 3    Com golaço de Suárez, Grêmio vence e afunda In...
# 4    Congresso vota nova regra fiscal e define plan...
# ..                                                 ...
# 600  Coroação de Charles 3º: por que príncipe Harry...
# 601  O desconhecido parentesco entre Charles 3º e a...
# 602  Defesa apostará em falta de provas para desvin...
# 603  Morre Palmirinha, carismática apresentadora de...
# 604  Os filhos da rainha Camilla Parker terão algum...
#
#                                                   Link
# 0    https://g1.globo.com/go/goias/noticia/2023/05/...
# 1    https://g1.globo.com/tecnologia/noticia/2023/0...
# 2    https://ge.globo.com/rj/futebol/brasileirao-se...
# 3    https://ge.globo.com/rs/futebol/brasileirao-se...
# 4    https://g1.globo.com/politica/noticia/2023/05/...
# ..                                                 ...
# 600  https://www.bbc.com/portuguese/articles/c6p9nq...
# 601  https://www.bbc.com/portuguese/articles/cndgzj...
# 602  https://www.cnnbrasil.com.br/politica/defesa-a...
# 603  https://www.cnnbrasil.com.br/entretenimento/pa...
# 604  https://www.cnnbrasil.com.br/internacional/os-...
#
# [605 rows x 2 columns]

# %%
# Remove lines specified to link of Twitter
dff.drop( index = dff.index[  dff['Title'] == 'Twitter'  ] )
dff.drop( index = dff.index[  dff['Title'] == 'Facebook'  ] )
dff.drop( index = dff.index[  dff['Title'] == 'Instagram'  ] )
# Out:
#                                                  Title  \
# 0    Imprensa internacional repercute escândalo no ...
# 1    Instagram volta a funcionar depois de mais de ...
# 2    Flamengo derrota o Corinthians com gol nos acr...
# 3    Com golaço de Suárez, Grêmio vence e afunda In...
# 4    Congresso vota nova regra fiscal e define plan...
# ..                                                 ...
# 600  Coroação de Charles 3º: por que príncipe Harry...
# 601  O desconhecido parentesco entre Charles 3º e a...
# 602  Defesa apostará em falta de provas para desvin...
# 603  Morre Palmirinha, carismática apresentadora de...
# 604  Os filhos da rainha Camilla Parker terão algum...
#
#                                                   Link
# 0    https://g1.globo.com/go/goias/noticia/2023/05/...
# 1    https://g1.globo.com/tecnologia/noticia/2023/0...
# 2    https://ge.globo.com/rj/futebol/brasileirao-se...
# 3    https://ge.globo.com/rs/futebol/brasileirao-se...
# 4    https://g1.globo.com/politica/noticia/2023/05/...
# ..                                                 ...
# 600  https://www.bbc.com/portuguese/articles/c6p9nq...
# 601  https://www.bbc.com/portuguese/articles/cndgzj...
# 602  https://www.cnnbrasil.com.br/politica/defesa-a...
# 603  https://www.cnnbrasil.com.br/entretenimento/pa...
# 604  https://www.cnnbrasil.com.br/internacional/os-...
#
# [604 rows x 2 columns]

# %%
dff.to_csv('news.csv', sep=';', index=False)

# %%
dff.to_json( 'news.json' )
