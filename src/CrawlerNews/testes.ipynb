# %%
from crawler import CrawlerNews

# %%
b = CrawlerNews()

# %%
b.bnRequest(url='https://www.bbc.com/portuguese')
# Out:
# '<!doctype html><html lang="pt-BR" class="no-js" dir="ltr"><head><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" name="robots" content="noodp, noydir, max-image-preview:large"/><meta data-react-helmet="true" name="theme-color" content="#B80000"/><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta data-react-helmet="true" name="apple-mobile-web-app-title" content="BBC News Brasil"/><meta data-react-helmet="true" name="application-name" content="BBC News Brasil"/><meta data-react-helmet="true" name="description" content="Na BBC Brasil você fica por dentro do que acontece no Brasil e no mundo. Com redações em Londres e São Paulo e mais de 200 repórteres internacionais, nossa cobertura leva a você as principais notícias de política, economia, ciência, saúde e comportamento."/><meta data-react-helmet="true" property=
# ...

# %%
b.data = b.bnRequest(url='https://www.bbc.com/portuguese')

# %%
b.data
# Out:
# '<!doctype html><html lang="pt-BR" class="no-js" dir="ltr"><head><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" name="robots" content="noodp, noydir, max-image-preview:large"/><meta data-react-helmet="true" name="theme-color" content="#B80000"/><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta data-react-helmet="true" name="apple-mobile-web-app-title" content="BBC News Brasil"/><meta data-react-helmet="true" name="application-name" content="BBC News Brasil"/><meta data-react-helmet="true" name="description" content="Na BBC Brasil você fica por dentro do que acontece no Brasil e no mundo. Com redações em Londres e São Paulo e mais de 200 repórteres internacionais, nossa cobertura leva a você as principais notícias de política, economia, ciência, saúde e comportamento."/><meta data-react-helmet="true" property=
# ...

# %%
b.url
# Out:
# 'https://www.bbc.com/portuguese'
